# %%
import warnings
warnings.filterwarnings('ignore')
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("")
conn = engine.connect()
data = pd.read_csv(r"C:\Users\Admin\Desktop\Coffee Shop Analysis SQL\coffee.csv")
data.to_sql('SALES', engine, index=False, if_exists='replace')
conn.close()
print("CSV has been loaded into MySQL table SALES successfully!")
# Out:
# CSV has been loaded into MySQL table SALES successfully!
